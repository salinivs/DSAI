# %%
import pandas as pd
import numpy as np

#read the dataset

df1=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')
df1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# Q1)Print first 5 and last 7 records

# %%
#print first 5 rows

df1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#print last 7 rows

df1.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %% [markdown]
# Q2)print total records and type of variables

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# Q3)Print the name of all the columns.

# %%
df1.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Q4)How is the dataset indexed?

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Q5)Which was the most ordered item? and How many items were ordered?

# %%
most = df1.groupby('item_name')
most= most.sum()
most = most.sort_values(['quantity'], ascending=False)
most.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# Q6)What was the most ordered item in the choice_description column?

# %%
most = df1.groupby('choice_description').sum()
most = most.sort_values(['quantity'], ascending=False)
most.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# Q7)Turn the item price into a float

# %%
def getprice(strprice):
    strtemp= strprice[1:-1]
    return float(strtemp)
df1['PriceNew']=df1['item_price'].apply(getprice)
df1.head()                                                    # ITEM PRICE IS CONVERT TO FLOAT-COLUMN NAME IS PriceNew
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  PriceNew
# 0                                                NaN     $2.39       2.39
# 1                                       [Clementine]     $3.39       3.39
# 2                                            [Apple]     $3.39       3.39
# 3                                                NaN     $2.39       2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98      16.98

# %% [markdown]
# Q8)print a data frame with only two columns item_name and item_price

# %%
a=df1[['item_name','item_price']]
a.set_index('item_name')
# Out:
#                                       item_price
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
# ...                                          ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
#
# [4622 rows x 1 columns]

# %% [markdown]
# Q9) delete the duplicates in item_name and quantity

# %%
df1.drop_duplicates(['item_name','quantity'])
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description item_price  PriceNew
# 0                                                   NaN     $2.39       2.39
# ...

# %% [markdown]
# Q10)select only the item_name and item_price columns

# %%
df1[['item_name','item_price']].set_index('item_name')
# Out:
#                                       item_price
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
# ...                                          ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
#
# [4622 rows x 1 columns]

# %% [markdown]
# Q11)sort item from the most to less expensive

# %%
df1.sort_values('PriceNew',ascending=False)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3936      1578         1                   Canned Soda
# 2922      1162         1                 Bottled Water
# 1396       567         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# 1457       591         1                   Canned Soda
#
#                                      choice_description item_price  PriceNew
# 3598                                                NaN    $44.25      44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25      35.25
# ...

# %% [markdown]
# Q12)What was the quantity of the most expensive item ordered?

# %%
df1.sort_values('PriceNew',ascending=False).max()
# Out:
# order_id                   1834
# quantity                     15
# item_name     Veggie Soft Tacos
# item_price               $9.39
# PriceNew                  44.25
# dtype: object

# %% [markdown]
# Q13)How many times were a Veggie Salad Bowl ordered?

# %%
b=df1['item_name'].value_counts(ascending=True)
b['Veggie Salad Bowl']
# Out:
# 18
